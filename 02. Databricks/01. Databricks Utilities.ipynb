# %%
dbutils.help()

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.combobox(
    name="top_n_records",
    defaultValue="1",
    choices=["1", "2", "3", "4"],
    label="Top N Records",
)

# %%
dbutils.widgets.get("top_n_records")

# %%
dbutils.widgets.dropdown(
    name="environment",
    defaultValue="Development",
    choices=["Development", "Staging", "Production"],
    label="Environment Type",
)

# %%
print(dbutils.widgets.get("top_n_records"))
dbutils.widgets.get("environment")

# %%
dbutils.widgets.multiselect(name="user_input", defaultValue="2G", choices=["2G", "3G", "4G"], label="Technology")

# %%
dbutils.widgets.get("user_input")

# %%
dbutils.widgets.remove("top_n_records")

# %%
dbutils.widgets.removeAll()
