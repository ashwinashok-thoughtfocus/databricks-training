# %%
dbutils.notebook.help()

# %%
execution_status = dbutils.notebook.run("./ChildNotebook01", timeout_seconds=100)
execution_status

# %%
execution_status = dbutils.notebook.run(
    "./ChildNotebook01", timeout_seconds=100, arguments={"environment": "Staging"}
)
execution_status
