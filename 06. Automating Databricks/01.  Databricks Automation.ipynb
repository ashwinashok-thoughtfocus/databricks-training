# %%
DATABRICKS_TOKEN=""
DATABRICKS_BASE_URL=""

# %% [markdown]
# # Cluster API

# %% [markdown]
# ## Get available clusters

# %%
CLUSTERS_REST_ENDPOINT="/api/2.0/clusters/list"

# %% [markdown]
# ### CURL

# %%
# %sh

curl -X GET \
    -H "Authorization: Bearer $DATABRICKS_TOKEN" \
    $DATABRICKS_BASE_URL$REST_ENDPOINT

# %% [markdown]
# ### Python

# %%
import requests
import json

HEADERS = {"Authorization": f"Bearer {DATABRICKS_TOKEN}"}

response = requests.get(url=f"{DATABRICKS_BASE_URL}{REST_ENDPOINT}", headers=HEADERS)
print(json.dumps(json.loads(response.text)))

# %% [markdown]
# ## Create a cluster

# %%
REST_ENDPOINT = "/api/2.0/clusters/create"

# %%
import requests
import json

HEADERS = {
            "Authorization": f"Bearer {DATABRICKS_TOKEN}",
            "Content-Type": "application/json"
        }

# %% [markdown]
# ## Stop a cluster

# %%
CLUSTERS_REST_ENDPOINT = '/api/2.0/clusters/delete'

# %% [markdown]
# ## Delete a cluster

# %%
CLUSTERS_REST_ENDPOINT = '/api/2.0/clusters/permanent-delete'

# %% [markdown]
# ## Start a cluster

# %%
CLUSTERS_REST_ENDPOINT = '/api/2.0/clusters/start'

# %% [markdown]
# ## Restart a cluster

# %%
CLUSTERS_REST_ENDPOINT = '/api/2.0/clusters/restart'

# %% [markdown]
# # Jobs API

# %% [markdown]
# ## Get all jobs

# %%
JOBS_REST_ENDPOINT = '/api/2.0/jobs/list'

# %% [markdown]
# #### CURL

# %%
# %sh

curl -X GET \
    -H "Authorization: Bearer $DATABRICKS_TOKEN" \
    $DATABRICKS_BASE_URL$JOBS_REST_ENDPOINT

# %% [markdown]
# ## Get single job

# %%
QUERY_PARAMETER='?job_id=...'

# %% [markdown]
# ### CURL

# %%
# %sh

curl -X GET \
    -H "Authorization: Bearer $DATABRICKS_TOKEN" \
    $DATABRICKS_BASE_URL$JOBS_REST_ENDPOINT$QUERY_PARAMETER
